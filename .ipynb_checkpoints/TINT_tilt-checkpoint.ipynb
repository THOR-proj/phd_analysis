# %%
# Core 
import datetime
import os
import glob
from IPython.display import HTML, Image, display
import tempfile
import shutil

# Analysis 
import xarray as xr
import numpy as np
import pyproj as pp
import scipy as sp
import metpy as mp

# Plotting 
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
from matplotlib import rcParams
import matplotlib.ticker as mticker
from matplotlib.animation import FuncAnimation
import matplotlib.colors as colors

# Debugging 
import pdb
# %load_ext line_profiler

# Radar Tools
import pyart
from tint.data_utils import get_nexrad_keys, read_nexrad_key
from tint import Cell_tracks, animate
from tint.visualization import embed_mp4_as_gif
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# Store filenames for an example day of data
filenames = sorted(glob.glob('/g/data/rr5/CPOL_radar/CPOL_level_1b/GRIDDED/GRID_70km_1000m/2016/20161220/*.nc'))
grids_low = (pyart.io.read_grid(fn, include_fields = 'reflectivity') for fn in filenames)
grids_mid = (pyart.io.read_grid(fn, include_fields = 'reflectivity') for fn in filenames)

# Specify bounds of CPOL 1000 m gridded dataset
lon_min = 130.40
lon_max = 131.69

lat_max = -11.61
lat_min = -12.87

# Define settings for low and mid level tracking
settings_low = {
    'MIN_SIZE' : 100, 
    'FIELD_THRESH' : 40,
    'GS_ALT' : 1500,
}

settings_mid = {
    'MIN_SIZE' : 80, 
    'FIELD_THRESH' : 30,
    'GS_ALT' : 5000,
}

# Calculate high and low level tracks
tracks_obj_low  = Cell_tracks()
tracks_obj_mid  = Cell_tracks()

for parameter in ['MIN_SIZE', 'FIELD_THRESH', 'GS_ALT']:
    tracks_obj_low.params[parameter] = settings_low[parameter]
    tracks_obj_mid.params[parameter] = settings_mid[parameter]

# Calculate tracks
tracks_obj_low.get_tracks(grids)
tracks_obj_mid.get_tracks(grids)
# Out:
# Writing tracks for scan 0
# No cells found in scan 1
# No cells found in scan 2
# No cells found in scan 3
# Writing tracks for scan 4
# Writing tracks for scan 5
# Writing tracks for scan 6
# No cells found in scan 7
# No cells found in scan 8
# Writing tracks for scan 9
# No cells found in scan 10
# No cells found in scan 11
# Writing tracks for scan 12
# Writing tracks for scan 13
# Writing tracks for scan 14
# Writing tracks for scan 15
# Writing tracks for scan 16
# Writing tracks for scan 17
# Writing tracks for scan 18
# Writing tracks for scan 19
# Writing tracks for scan 20
# No cells found in scan 21
# Writing tracks for scan 22
# Writing tracks for scan 23
# Writing tracks for scan 24
# Writing tracks for scan 25
# Writing tracks for scan 26
# Writing tracks for scan 27
# Writing tracks for scan 28
# Writing tracks for scan 29
# No cells found in scan 30
# No cells found in scan 31
# No cells found in scan 32
# No cells found in scan 33
# No cells found in scan 34
# No cells found in scan 35
# No cells found in scan 36
# No cells found in scan 37
# No cells found in scan 38
# No cells found in scan 39
# No cells found in scan 40
# No cells found in scan 41
# No cells found in scan 42
# No cells found in scan 43
# No cells found in scan 44
# No cells found in scan 45
# No cells found in scan 46
# No cells found in scan 47
# No cells found in scan 48
# No cells found in scan 49
# No cells found in scan 50
# No cells found in scan 51
# No cells found in scan 52
# Writing tracks for scan 53
# Writing tracks for scan 54
# Writing tracks for scan 55
# Writing tracks for scan 56
# Writing tracks for scan 57
# Writing tracks for scan 58
# Writing tracks for scan 59
# Writing tracks for scan 60
# Writing tracks for scan 61
# No cells found in scan 62
# No cells found in scan 63
# No cells found in scan 64
# No cells found in scan 65
# Writing tracks for scan 66
# Writing tracks for scan 67
# No cells found in scan 68
# Writing tracks for scan 69
# Writing tracks for scan 70
# Writing tracks for scan 71
# Writing tracks for scan 72
# No cells found in scan 73
# No cells found in scan 74
# No cells found in scan 75
# Writing tracks for scan 76
# Writing tracks for scan 77
# Writing tracks for scan 78
# Writing tracks for scan 79
# No cells found in scan 80
# No cells found in scan 81
# No cells found in scan 82
# No cells found in scan 83
# No cells found in scan 84
# No cells found in scan 85
# Writing tracks for scan 86
# Writing tracks for scan 87
# Writing tracks for scan 88
# Writing tracks for scan 89
# Writing tracks for scan 90
# Writing tracks for scan 91
# No cells found in scan 92
# Writing tracks for scan 93
# No cells found in scan 94
# Writing tracks for scan 95
# Writing tracks for scan 96
# Writing tracks for scan 97
# Writing tracks for scan 98
# Writing tracks for scan 99
# Writing tracks for scan 100
# Writing tracks for scan 101
# Writing tracks for scan 102
# Writing tracks for scan 103
# Writing tracks for scan 104
# Writing tracks for scan 105
# Writing tracks for scan 106
# Writing tracks for scan 107
# Writing tracks for scan 108
# Writing tracks for scan 109
# Writing tracks for scan 110
# Writing tracks for scan 111
# Writing tracks for scan 112
# Writing tracks for scan 113
# Writing tracks for scan 114
# Writing tracks for scan 115
# Writing tracks for scan 116
# Writing tracks for scan 117
# Writing tracks for scan 118
# Writing tracks for scan 119
# Writing tracks for scan 120
# Writing tracks for scan 121
# Writing tracks for scan 122
# Writing tracks for scan 123
# Writing tracks for scan 124
# Writing tracks for scan 125
# Writing tracks for scan 126
#
#
# time elapsed 0.3 minutes
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-32-0e05c1f30f82> in <module>
#      33 # Calculate tracks
#      34 tracks_obj_low.get_tracks(grids)
# ---> 35 tracks_obj_mid.get_tracks(grids)
#
# ~/TINT/tint/tracks.py in get_tracks(self, grids)
#     152         if self.record is None:
#     153             # tracks object being initialized
# --> 154             grid_obj2 = next(grids)
#     155             self.grid_size = get_grid_size(grid_obj2)
#     156             self.radar_info = get_radar_info(grid_obj2)
#
# StopIteration:

# %%
tracks_obj_mid.params
# Out:
# {'FIELD_THRESH': 30,
#  'MIN_SIZE': 80,
#  'SEARCH_MARGIN': 4000,
#  'FLOW_MARGIN': 10000,
#  'MAX_FLOW_MAG': 50,
#  'MAX_DISPARITY': 999,
#  'MAX_SHIFT_DISP': 15,
#  'ISO_THRESH': 8,
#  'ISO_SMOOTH': 3,
#  'GS_ALT': 5000}

# %%
tracks_obj_low.params
# Out:
# {'FIELD_THRESH': 30,
#  'MIN_SIZE': 80,
#  'SEARCH_MARGIN': 4000,
#  'FLOW_MARGIN': 10000,
#  'MAX_FLOW_MAG': 50,
#  'MAX_DISPARITY': 999,
#  'MAX_SHIFT_DISP': 15,
#  'ISO_THRESH': 8,
#  'ISO_SMOOTH': 3,
#  'GS_ALT': 5000}

# %%
tracks_obj_low.tracks
# Out:
#                         time   grid_x   grid_y       lon      lat    area  \
# scan uid
# 0    0   2016-12-20 02:40:05   44.789   10.814  130.8139 -12.7794   247.0
#      1   2016-12-20 02:40:05   49.448   73.307  130.8512 -12.2218   600.0
#      2   2016-12-20 02:40:05   79.467   88.422  131.1272 -12.0870   199.0
#      3   2016-12-20 02:40:05   21.903  119.829  130.6035 -11.7989   843.0
#      4   2016-12-20 02:40:05   89.420  126.094  131.2190 -11.7452  1008.0
#      5   2016-12-20 02:40:05  121.519  115.644  131.5222 -11.8348   104.0
#      6   2016-12-20 02:40:05   54.527  117.022  130.9066 -11.8262    93.0
#      7   2016-12-20 02:40:05  129.602  135.841  131.5954 -11.6548   113.0
